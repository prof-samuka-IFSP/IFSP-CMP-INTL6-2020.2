# %% [markdown]
# # Relatório - Imóveis Residenciais

# %%
import pandas as pd
dataset_residencial = pd.read_csv('datasets/aluguel_residencial.csv', sep=';')
dataset_residencial.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# 4         NaN   NaN

# %% [markdown]
# ### Apartamentos

# %%
# alternativa 1
dataset_residencial.query('Tipo == "Apartamento"')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# 5      Apartamento              Cachambi        2      0       0    50
# 8      Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 22573  Apartamento        Vila Valqueire        2      0       0    52
# 22575  Apartamento                 Méier        2      0       0    70
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 2       800.0       390.0  20.0
# 3       800.0       230.0   NaN
# ...

# %%
# alternativa 2
selecao = dataset_residencial['Tipo'] == 'Apartamento'
apartamentos = dataset_residencial.loc[selecao]
apartamentos
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# 5      Apartamento              Cachambi        2      0       0    50
# 8      Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 22573  Apartamento        Vila Valqueire        2      0       0    52
# 22575  Apartamento                 Méier        2      0       0    70
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 2       800.0       390.0  20.0
# 3       800.0       230.0   NaN
# ...

# %%
print(f'Há {apartamentos.shape[0]} apartamentos no dataset')
# Out:
# Há 19532 apartamentos no dataset

# %% [markdown]
# ### Casa == Casa, Casa de Condomínio, Casa de Vila

# %%
dataset_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
selecao = dataset_residencial['Tipo'].isin(['Casa', 'Casa de Condomínio', 'Casa de Vila'])
## alternativa 2
# selecao = (dataset_residencial['Tipo'] == 'Casa') | (dataset_residencial['Tipo'] == 'Casa de Condomínio') | (dataset_residencial['Tipo'] == 'Casa de Vila')
selecao
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 22575    False
# 22576    False
# 22577    False
# 22578    False
# 22579    False
# Name: Tipo, Length: 22580, dtype: bool

# %%
casas = dataset_residencial[selecao]
casas
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1                    Casa          Jardim Botânico        2      0       1
# 6      Casa de Condomínio          Barra da Tijuca        5      4       5
# 7      Casa de Condomínio                    Ramos        2      2       0
# 14     Casa de Condomínio                  Taquara        3      1       1
# 18     Casa de Condomínio          Barra da Tijuca        4      3       2
# ...                   ...                      ...      ...    ...     ...
# 22545  Casa de Condomínio  Freguesia (Jacarepaguá)        3      3       1
# 22547                Casa            Bento Ribeiro        2      1       0
# 22555  Casa de Condomínio          Barra da Tijuca        3      5       3
# 22558                Casa                   Centro        5      0       1
# 22574  Casa de Condomínio          Barra da Tijuca        5      3       4
#
#        Area    Valor  Condominio    IPTU
# ...

# %%
casas['Tipo'].unique()
# Out:
# array(['Casa', 'Casa de Condomínio', 'Casa de Vila'], dtype=object)

# %%
casas['Tipo'].drop_duplicates().to_frame()
# Out:
#                   Tipo
# 1                 Casa
# 6   Casa de Condomínio
# 85        Casa de Vila

# %%
print(f'Há {casas.shape[0]} Casas no dataset')
# Out:
# Há 2212 Casas no dataset

# %% [markdown]
# ### Imóveis Residenciais com área entre 50 e 100 m2

# %%
dataset_residencial.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# 4         NaN   NaN

# %%
selecao = (dataset_residencial['Area'] >= 50) & (dataset_residencial['Area'] <= 100)

# %%
imoveis_area_entre_50_100 = dataset_residencial[selecao]
imoveis_area_entre_50_100
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 1                    Casa  Jardim Botânico        2      0       1   100
# 4             Apartamento     Vista Alegre        3      1       0    70
# 5             Apartamento         Cachambi        2      0       0    50
# 7      Casa de Condomínio            Ramos        2      2       0    65
# 9             Apartamento           Grajaú        2      1       0    70
# ...                   ...              ...      ...    ...     ...   ...
# 22570         Apartamento           Leblon        3      0       1    80
# 22573         Apartamento   Vila Valqueire        2      0       0    52
# 22575         Apartamento            Méier        2      0       0    70
# 22577         Apartamento      Jacarepaguá        3      1       2    78
# 22579         Apartamento           Leblon        2      0       0    70
#
#         Valor  Condominio   IPTU
# 1      7000.0         NaN    NaN
# ...

# %%
imoveis_area_entre_50_100['Tipo'].value_counts().to_frame()
# Out:
#                     Tipo
# Apartamento         9720
# Casa                 347
# Casa de Vila         133
# Casa de Condomínio   121
# Quitinete             18

# %% [markdown]
# ### Imóveis com ao menos 3 quartos e aluguel menor que R$ 2500.00
