# %% [markdown]
# # Tutorial (Básico) de Python
#
# Neste tutorial, vamos aprender os conceitos básicos para desenvolvermos nossos primeiros programas em Python! <br/>
# Boa parte dos exemplos deste tutorial é inspirado no [curso de Python do Kaggle\(https://www.kaggle.com/learn/python).

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# ## Variáveis
#
# ### Tipos
# Python tem diferentes tipos de dados, mas no fundo, *tudo é um objeto*. <br/>
# Variáveis podem ser definidas em qualquer lugar.
#
# Veja alguns tipos:
#
# | Tipo    | Exemplo           |
# |---------|-------------------|
# | Integer | 1 10 -4           |
# | Float   | 1.0 -0.223 3.1415 |
# | String  | "Hello world"     |

# %% [markdown]
# ## Instanciando variáveis

# %%
nome = "Luke Skywalker"
idade = 18
peso = 70.5

# %%
nome
# Out:
# 'Luke Skywalker'

# %%
print(nome)
print(nome, idade, peso)
# Out:
# Luke Skywalker
# Luke Skywalker 18 70.5

# %% [markdown]
# ### Type()
# Use a função <code>type()</code> para descobrir o tipo de uma variável.

# %%
type(nome), type(idade), type(peso)  # imprimirá uma tupla (veremos isso depois!)
# Out:
# (str, int, float)

# %% [markdown]
# ### Dir()
# Use a função <code>dir()</code> para descobrir **todos os métodos** associados a um objeto:

# %%
dir(nome)  # veja todos os métodos associados a uma string
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %% [markdown]
# ### Usando métodos
# Métodos podem ser acessados usando: <code>objeto.metodo</code>

# %%
nome.upper()
# Out:
# 'LUKE SKYWALKER'

# %% [markdown]
# ### Atribuição Múltipla

# %%
nome, idade, peso = "Yoda", 1000, 10.5

print(nome, idade, peso)
# Out:
# Yoda 1000 10.5

# %% [markdown]
# ### Python é uma linguagem *case-sensitive*

# %%
a = 10
b = 5
c = a + b
print(c)
# Out:
# 15

# %%
B = 1
d = a + B
print(d)
# Out:
# 11

# %% [markdown]
# ### Dinamicamente e Fortemente tipada
#
# **Dinamicamente:** o tipo é definido no momento da atribuição
# **Fortemente:** o interpretador não muda o tipo de uma variável inesperadamente

# %%
print(type(a))

a = "10"
print(type(a))

c = a + b
# Out:
# <class 'int'>
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-bbc2a3859ca6> in <module>
#       4 print(type(a))
#       5
# ----> 6 c = a + b
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### Conversão de Tipos (*Casting*)

# %%
c = int(a) + b  # a é string e uma cópia de seu valor (não a variável propriamente dita) foi convertido para inteiro
print(c)
# Out:
# 15

# %%
print(a)
print(type(a))
# Out:
# 10
# <class 'str'>

# %%
print(int(4.5))  # removendo os decimais de um float
# Out:
# 4

# %%
str(10)  # convertendo um inteiro em uma string
# Out:
# '10'

# %% [markdown]
# ### Operadores Aritméticos
#
# | Operador     | Nome                 | Descrição                                                                            |
# |--------------|----------------------|--------------------------------------------------------------------------------------|
# | ``a + b``    | Adição               | Soma de ``a`` e ``b``                                                                |
# | ``a - b``    | Subtração            | Diferença de ``a`` e ``b``                                                           |
# | ``a * b``    | Multiplicação        | Produto de ``a`` e ``b``                                                             |
# | ``a / b``    | Divisão 'verdadeira' | Quociente de ``a`` e ``b``                                                           |
# | ``a // b``   | Piso da Divisão      | Quociente de ``a`` e ``b``, removendo partes fracionadas (arredondamento para baixo) |
# | ``a % b``    | Módulo               | Resto da divisão de a ``a`` por ``b``                                                |
# | ``a ** b``   | Exponenciação        | ``a`` elevado a ``b``                                                                |
# | ``-a``       | Negação              | Negativo de ``a``                                                                    |

# %%
# Divisão 'verdadeira'
print(5 / 2)
print(6 / 2)
# Out:
# 2.5
# 3.0

# %%
# Piso da Divisão
print(5 // 2)
print(6 // 2)
# Out:
# 2
# 3

# %% [markdown]
# ### A função print()
# A função _print()_ imprime uma string na tela/console. <br/>
# Uma string pode ser definida com **aspas simples ''** ou **aspas duplas ""**.
#
# Por convenção, a comunidade usa **aspas simples ''**

# %%
print('Imprimindo com aspas simples!')
print("Imprimindo com aspas duplas!")
# Out:
# Imprimindo com aspas simples!
# Imprimindo com aspas duplas!

# %% [markdown]
# <br/>Para imprimir valores de _variáveis_ junto com uma _string/texto_, utilize a letra **_f_** antes das primeiras aspas, e coloque a variável entre **_{}_** (Python 3.6+):

# %%
print(f'Meu nome eh {nome}')
print(f'Tenho {idade} anos')
print(f'Peso {peso} kg')
print('')  # print sempre pula uma linha por padrão

# ou tudo na mesma linha, pulando uma linha com \n
print(f'Meu nome eh: {nome}\nTenho {idade} anos\nPeso {peso} kg')
# Out:
# Meu nome eh Yoda
# Tenho 1000 anos
# Peso 10.5 kg
#
# Meu nome eh: Yoda
# Tenho 1000 anos
# Peso 10.5 kg

# %% [markdown]
# <br/>
# Alternativa, temos outras formas de impressão vindas de versões mais antigas do Python, porém ainda válidas:

# %%
print('Meu nome eh %s' % nome)
print(f'Tenho %d anos' % idade)
print(f'Peso %f kg' % peso)
print('')  # print sempre pula uma linha por padrão

# ou tudo na mesma linha, pulando uma linha com \n
print('Meu nome eh: %s\nTenho %d anos\nPeso %f kg' % (nome, idade, peso))
# Out:
# Meu nome eh Yoda
# Tenho 1000 anos
# Peso 10.500000 kg
#
# Meu nome eh: Yoda
# Tenho 1000 anos
# Peso 10.500000 kg

# %%
print('Meu nome eh {0}'.format(nome))
print('Tenho {0} anos'.format(idade))
print('Peso {0} kg'.format(peso))
print('')  # print sempre pula uma linha por padrão

# ou tudo na mesma linha, pulando uma linha com \n
print('Meu nome eh: {0}\nTenho {1} anos\nPeso {2} kg'.format(nome, idade, peso))
# Out:
# Meu nome eh Yoda
# Tenho 1000 anos
# Peso 10.5 kg
#
# Meu nome eh: Yoda
# Tenho 1000 anos
# Peso 10.5 kg
