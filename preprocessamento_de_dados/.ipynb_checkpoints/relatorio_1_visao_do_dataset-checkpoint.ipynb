# %% [markdown]
# # Relatório 1 - Visão do Dataset (Tipos de Dados)
# - Dataset: [aluguel.csv](./datasets/aluguel.csv)

# %% [markdown]
# ## Lendo o Dataset

# %%
import pandas as pd
pd.read_csv('datasets/aluguel.csv')
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
dataset = pd.read_csv('datasets/aluguel.csv', sep=';')
dataset
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %% [markdown]
# ## Visão Geral do Dataset

# %%
dataset.shape
# Out:
# (32960, 9)

# %%
print(f'O dataset possui {dataset.shape[0]} linhas/registros/tuplas/exemplos (Imóveis) e {dataset.shape[1]} colunas/atributos/variáveis')
# Out:
# O dataset possui 32960 linhas/registros/tuplas/exemplos (Imóveis) e 9 colunas/atributos/variáveis

# %%
dataset.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
type(dataset.dtypes)
# Out:
# pandas.core.series.Series

# %%
dataset.dtypes.to_frame()
# Out:
#                   0
# Tipo         object
# Bairro       object
# Quartos       int64
# Vagas         int64
# Suites        int64
# Area          int64
# Valor       float64
# Condominio  float64
# IPTU        float64

# %%
tipo_de_dados = pd.DataFrame(dataset.dtypes, columns = ['Tipo de Dados'])
tipo_de_dados
# Out:
#            Tipo de Dados
# Tipo              object
# Bairro            object
# Quartos            int64
# Vagas              int64
# Suites             int64
# Area               int64
# Valor            float64
# Condominio       float64
# IPTU             float64

# %%
tipo_de_dados.reset_index()
# Out:
#         index Tipo de Dados
# 0        Tipo        object
# 1      Bairro        object
# 2     Quartos         int64
# 3       Vagas         int64
# 4      Suites         int64
# 5        Area         int64
# 6       Valor       float64
# 7  Condominio       float64
# 8        IPTU       float64

# %%
tipo_de_dados
# Out:
#            Tipo de Dados
# Tipo              object
# Bairro            object
# Quartos            int64
# Vagas              int64
# Suites             int64
# Area               int64
# Valor            float64
# Condominio       float64
# IPTU             float64

# %%
tipo_de_dados.columns.name = 'Atributos/Variáveis'  # altera o nome da "coluna" do index
tipo_de_dados
# Out:
# Atributos/Variáveis Tipo de Dados
# Tipo                       object
# Bairro                     object
# Quartos                     int64
# Vagas                       int64
# Suites                      int64
# Area                        int64
# Valor                     float64
# Condominio                float64
# IPTU                      float64
